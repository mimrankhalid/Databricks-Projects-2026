# %% [markdown]
# #Init

# %%
import pyspark.sql.functions as F
from pyspark.sql.functions import col, trim, lit, when, count, countDistinct
from pyspark.sql.types import StringType

# %% [markdown]
# #Read the table from Silver layer

# %%
df = spark.table("workspace.silver.crm_customers")

# %%
df.display()

# %%
query = """
SELECT 
customer_id
,customer_key
,customer_first_name
,customer_last_name
,marital_status
,gender
,created_date
FROM workspace.silver.crm_customers
Order By created_date
"""
df=spark.sql(query)
#df.display()

# %%
#df.display()

# %%
(
df.write
.mode("overwrite")
.format("delta")
.saveAsTable("workspace.gold.dim_customers")
)
