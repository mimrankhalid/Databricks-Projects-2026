# %% [markdown]
# reading from CSV file

# %%
df=(spark.read.option("header","true").option("inferSchema","true").csv("/Volumes/workspace/bronze/source_systems/source_crm/cust_info.csv"))
#df.display()

# %% [markdown]
# Write the same AS-IS data to Bronze scheme

# %%
df.write.mode("overwrite").saveAsTable("bronze.crm_cust_info")

# %%
df=(spark.read.option("header","true").option("inferSchema","true").csv("/Volumes/workspace/bronze/source_systems/source_crm/prd_info.csv"))

df.write.mode("overwrite").saveAsTable("bronze.crm_prd_info")

# %%
df=(spark.read.option("header","true").option("inferSchema","true").csv("/Volumes/workspace/bronze/source_systems/source_crm/sales_details.csv"))

df.write.mode("overwrite").saveAsTable("bronze.crm_sales_details")

# %%
df=(spark.read.option("header","true").option("inferSchema","true").csv("/Volumes/workspace/bronze/source_systems/source_erp/CUST_AZ12.csv"))

df.write.mode("overwrite").saveAsTable("bronze.erp_CUST_AZ12")

# %%
df=(spark.read.option("header","true").option("inferSchema","true").csv("/Volumes/workspace/bronze/source_systems/source_erp/LOC_A101.csv"))

df.write.mode("overwrite").saveAsTable("bronze.erp_LOC_A101")

# %%
df=(spark.read.option("header","true").option("inferSchema","true").csv("/Volumes/workspace/bronze/source_systems/source_erp/PX_CAT_G1V2.csv"))

df.write.mode("overwrite").saveAsTable("bronze.erp_PX_CAT_G1V2")
